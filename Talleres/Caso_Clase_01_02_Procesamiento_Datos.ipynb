# %% [markdown]
# # CASO PRÁCTICO — Procesamiento de Datos
# ## Análisis y preparación de datos de ventas de una tienda
#
# **Nivel:** Medio
# **Materia:** Procesamiento de Datos
# **Temas:** Clase 01 — Introducción al Procesamiento de Datos; Clase 02 — Tipos y Estructuras de Datos
# **Modalidad:** Individual
# **Lenguaje:** Python
#
# ### 1. Contexto del caso
#
# Una tienda de tecnología desea analizar las ventas realizadas durante una semana para conocer su comportamiento comercial. Los datos fueron registrados de manera manual y se encuentran en diferentes estructuras de Python. Antes de generar indicadores, es necesario **organizar, validar, transformar y procesar los datos**.
#
# Como estudiante de Procesamiento de Datos, deberá construir un pequeño flujo de procesamiento que permita convertir los datos originales en información útil para la toma de decisiones.
#
# ### 2. Datos iniciales
#
# Utilice exactamente los siguientes datos para desarrollar el caso:
#
# ```python
# productos = [
#     ("Laptop", "Computación", 850.00),
#     ("Mouse", "Accesorios", 25.00),
#     ("Teclado", "Accesorios", 45.00),
#     ("Monitor", "Computación", 320.00),
#     ("Audífonos", "Audio", 80.00)
# ]
#
# ventas = [
#     {"id": 1, "producto": "Laptop", "cantidad": 2, "dia": "Lunes"},
#     {"id": 2, "producto": "Mouse", "cantidad": 8, "dia": "Lunes"},
#     {"id": 3, "producto": "Teclado", "cantidad": 5, "dia": "Martes"},
#     {"id": 4, "producto": "Monitor", "cantidad": 3, "dia": "Miércoles"},
#     {"id": 5, "producto": "Audífonos", "cantidad": 6, "dia": "Miércoles"},
#     {"id": 6, "producto": "Mouse", "cantidad": 10, "dia": "Jueves"},
#     {"id": 7, "producto": "Laptop", "cantidad": 1, "dia": "Viernes"},
#     {"id": 8, "producto": "Monitor", "cantidad": 4, "dia": "Viernes"}
# ]
# ```
#
# ### 3. Objetivo
#
# Desarrollar un programa en Python que aplique conceptos básicos de procesamiento de datos y estructuras de datos para **integrar información, realizar validaciones, calcular indicadores y generar un resumen de resultados**.
#
# ### 4. Actividades a desarrollar
#
# #### Parte A — Exploración y tipos de datos
# 1. Crear las variables `productos` y `ventas` con los datos proporcionados.
# 2. Identificar mediante Python el tipo de dato de las variables principales y de al menos un elemento de cada estructura.
# 3. Explicar brevemente por qué se utilizan una **lista, tuplas y diccionarios** en este caso.
# 4. Determinar cuántos productos diferentes y cuántos registros de ventas existen.
#
# #### Parte B — Transformación de estructuras
# 5. Construir un diccionario llamado `precios` cuya clave sea el nombre del producto y cuyo valor sea su precio.
# 6. Construir un diccionario llamado `categorias` que relacione cada producto con su categoría.
# 7. Crear una nueva estructura `detalle_ventas` donde cada registro contenga, como mínimo: `id`, `producto`, `categoria`, `cantidad`, `precio_unitario`, `dia` y `subtotal`.
# 8. El campo `subtotal` debe calcularse como `cantidad * precio_unitario`.
#
# #### Parte C — Procesamiento y análisis
# 9. Calcular el **total de unidades vendidas**.
# 10. Calcular el **ingreso total** de la semana.
# 11. Determinar cuál fue el **producto con mayor cantidad de unidades vendidas**.
# 12. Determinar cuál fue el **producto que generó mayor ingreso**.
# 13. Calcular el ingreso acumulado por día y mostrarlo en una estructura apropiada.
# 14. Calcular el ingreso acumulado por categoría.
# 15. Identificar las ventas cuyo subtotal sea superior a **500 dólares**.
#
# #### Parte D — Validación de datos
# 16. Crear una función `validar_venta(venta)` que compruebe al menos:
#    - que `id` sea entero;
#    - que `producto` sea texto;
#    - que `cantidad` sea un entero mayor que cero;
#    - que `dia` sea texto.
# 17. Aplicar la función a todos los registros y mostrar cuántos registros son válidos.
# 18. Explicar qué problema podría producirse si una venta tuviera un producto que no existiera en `precios`.
#
# #### Parte E — Presentación de resultados
# 19. Mostrar un resumen final con:
#    - Total de productos registrados.
#    - Total de unidades vendidas.
#    - Ingreso total.
#    - Producto más vendido.
#    - Producto con mayor ingreso.
# 20. Presentar una conclusión de **5 a 8 líneas** explicando qué información obtenida podría ser útil para la administración de la tienda.
#
# ### 5. Restricciones técnicas
#
# - Utilizar Python y únicamente estructuras y funciones estudiadas en las Clases 01 y 02.
# - Utilizar listas, tuplas, diccionarios, variables, operadores, condicionales, ciclos y funciones.
# - No utilizar `pandas`, `numpy` u otras bibliotecas de análisis de datos.
# - El código debe estar organizado en funciones cuando una tarea pueda reutilizarse.
# - Los resultados deben ser legibles y estar acompañados de comentarios o explicaciones breves.
#
# ### 6. Entregable
#
# Completar este notebook (`.ipynb`) incluyendo **código, resultados de ejecución y respuestas explicativas**. El notebook debe ejecutarse de principio a fin sin errores.
#
# ### 7. Criterios de evaluación — 10 puntos
#
# | Criterio | Puntaje |
# |---|---:|
# | Identificación y uso correcto de tipos y estructuras de datos | 2.0 |
# | Transformación y organización de los datos | 2.0 |
# | Procesamiento y cálculo de indicadores | 2.5 |
# | Validación mediante funciones | 1.5 |
# | Presentación, interpretación y conclusión | 1.0 |
# | Calidad, orden y ejecución del código | 1.0 |
# | **Total** | **10.0** |
#
# ### Pregunta de reflexión
#
# **¿Por qué el procesamiento de datos requiere primero organizar y validar los datos antes de obtener conclusiones?** Responda relacionando su explicación con el caso desarrollado.

# %% [markdown]
# ## Desarrollo — Parte A: Exploración y tipos de datos
# Escriba aquí sus respuestas y código.

# %% [markdown]
# ## Desarrollo — Parte B: Transformación de estructuras
# Construya las estructuras solicitadas.

# %% [markdown]
# ## Desarrollo — Parte C: Procesamiento y análisis
# Calcule los indicadores solicitados y muestre los resultados.

# %% [markdown]
# ## Desarrollo — Parte D: Validación de datos
# Implemente la función de validación y aplíquela a los registros.

# %% [markdown]
# ## Desarrollo — Parte E: Presentación y conclusión
# Presente el resumen solicitado y escriba la conclusión de 5 a 8 líneas.

# %% [markdown]
# ## Reflexión final
# Responda: ¿Por qué el procesamiento de datos requiere primero organizar y validar los datos antes de obtener conclusiones?
