# %% [markdown]
# # CASO PRÁCTICO — Adquisición y Fuentes de Datos + Bases de Datos Orientadas a Documentos
#
# **Materia:** Procesamiento de Datos
# **Nivel:** Medio
# **Temas:** CLASE 03 — Adquisición y Fuentes de Datos; CLASE 04 — Bases de Datos Orientadas a Documentos
# **Lenguaje:** Python
# **Modalidad:** Individual
#
# ## 1. Contexto del caso
#
# Una empresa de comercio electrónico desea construir un pequeño sistema para recopilar información de productos provenientes de diferentes fuentes de datos. Actualmente, la información se encuentra distribuida entre un archivo CSV, un archivo JSON y un conjunto de registros obtenidos mediante una fuente externa simulada.
#
# El equipo de datos necesita integrar estas fuentes, identificar diferencias en su estructura, realizar una limpieza básica y almacenar la información en una estructura de datos orientada a documentos.
#
# Como estudiante de **Procesamiento de Datos**, deberá desarrollar un flujo básico de adquisición, integración y almacenamiento de datos utilizando Python y conceptos propios de las bases de datos orientadas a documentos.
#
# ## 2. Objetivo general
#
# Desarrollar un proceso de adquisición e integración de datos provenientes de diferentes fuentes, transformarlos a una estructura documental homogénea y simular operaciones básicas de una base de datos orientada a documentos.
#
# ## 3. Fuentes de datos
#
# Para el ejercicio se utilizarán tres fuentes:
#
# ### Fuente A — CSV
#
# Crear un archivo denominado `productos.csv` con el siguiente contenido:
#
# ```text
# id,nombre,categoria,precio,stock
# 101,Laptop Pro,Computacion,1250.00,8
# 102,Mouse Inalambrico,Accesorios,28.50,35
# 103,Teclado Mecanico,Accesorios,75.00,20
# 104,Monitor 27,Computacion,320.00,12
# 105,Auriculares Bluetooth,Audio,95.00,18
# ```
#
# ### Fuente B — JSON
#
# Crear un archivo denominado `productos_extra.json` con:
#
# ```json
# [
#   {"id": 106, "nombre": "Webcam HD", "categoria": "Perifericos", "precio": 65.0, "stock": 25},
#   {"id": 107, "nombre": "Disco SSD 1TB", "categoria": "Almacenamiento", "precio": 110.0, "stock": 14},
#   {"id": 108, "nombre": "Tablet 10", "categoria": "Moviles", "precio": 280.0, "stock": 9}
# ]
# ```
#
# ### Fuente C — Fuente externa simulada
#
# La siguiente lista representa datos recibidos desde una API externa:
#
# ```python
# datos_api = [
#     {"codigo": 109, "producto": "Smartwatch", "tipo": "Wearables", "valor": 150.0, "existencias": 11},
#     {"codigo": 110, "producto": "Parlante Bluetooth", "tipo": "Audio", "valor": 55.0, "existencias": 22},
#     {"codigo": 111, "producto": "Cable USB-C", "tipo": "Accesorios", "valor": 12.0, "existencias": 60}
# ]
# ```
#
# Observe que la Fuente C utiliza nombres de campos diferentes. Parte del problema consiste en **normalizar la estructura**.
#
# ## 4. Actividades a desarrollar
#
# ### Parte A — Adquisición y fuentes de datos
#
# 1. Crear los archivos `productos.csv` y `productos_extra.json` con los datos proporcionados.
# 2. Leer el archivo CSV utilizando el módulo `csv` de Python.
# 3. Leer el archivo JSON utilizando el módulo `json` de Python.
# 4. Crear la variable `datos_api` con los registros de la Fuente C.
# 5. Mostrar la cantidad de registros obtenidos de cada fuente.
# 6. Explicar brevemente la diferencia entre una fuente de datos **estructurada**, una fuente basada en **documentos JSON** y una fuente obtenida mediante una **API**.
#
# ### Parte B — Evaluación y calidad de las fuentes
#
# 7. Comparar los nombres de los campos utilizados por las tres fuentes.
# 8. Identificar qué campos representan la misma información aunque tengan nombres diferentes.
# 9. Determinar si existen datos faltantes en alguno de los registros.
# 10. Verificar que `id/codigo` sea entero, que el precio/valor sea numérico y que stock/existencias sea entero no negativo.
# 11. Crear una función `validar_producto()` que permita validar un registro antes de incorporarlo al conjunto integrado.
#
# ### Parte C — Integración y normalización
#
# 12. Transformar los registros de la Fuente C para utilizar los mismos nombres de campos que las Fuentes A y B.
# 13. Crear una lista llamada `productos_integrados` que contenga todos los productos de las tres fuentes.
# 14. Verificar que todos los documentos tengan exactamente los siguientes campos:
#
#    - `id`
#    - `nombre`
#    - `categoria`
#    - `precio`
#    - `stock`
#    - `fuente`
#
# 15. Agregar el campo `fuente` con los valores `CSV`, `JSON` o `API`, según corresponda.
# 16. Ordenar los productos por precio de mayor a menor.
#
# ### Parte D — Base de datos orientada a documentos
#
# 17. Explicar qué es una **base de datos orientada a documentos** y mencionar una característica que la diferencia de una base de datos relacional.
# 18. Representar cada producto como un documento Python equivalente a un documento JSON.
# 19. Crear una colección simulada llamada `coleccion_productos` utilizando una lista de diccionarios.
# 20. Implementar una función `insertar_documento()` para agregar productos a la colección.
# 21. Implementar una función `buscar_por_categoria(categoria)` que devuelva todos los documentos de una categoría determinada.
# 22. Implementar una función `buscar_por_precio(maximo)` que devuelva productos cuyo precio sea menor o igual al valor indicado.
# 23. Implementar una función `actualizar_stock(id_producto, nuevo_stock)` que modifique el stock de un producto.
# 24. Implementar una función `eliminar_producto(id_producto)` que elimine un documento de la colección.
#
# ### Parte E — Análisis de la información integrada
#
# 25. Determinar cuántos productos existen en total.
# 26. Calcular el valor total del inventario mediante `precio * stock`.
# 27. Identificar el producto con mayor precio.
# 28. Identificar el producto con mayor stock.
# 29. Determinar qué categoría concentra el mayor número de productos.
# 30. Mostrar los productos cuyo stock sea inferior a 10 unidades.
# 31. Mostrar el valor total del inventario agrupado por categoría.
#
# ### Parte F — Simulación de consultas documentales
#
# 32. Simular una consulta equivalente a:
#    - Buscar productos de la categoría `Accesorios`.
#    - Buscar productos con precio entre 50 y 300 dólares.
#    - Buscar productos con stock menor que 15.
# 33. Explicar cómo estas consultas podrían realizarse en una base de datos documental real como MongoDB.
# 34. Indicar dos ventajas y dos posibles desventajas de utilizar una base de datos orientada a documentos para este caso.
#
# ## 5. Restricciones técnicas
#
# - Utilizar Python.
# - Utilizar los módulos estándar `csv` y `json`.
# - No utilizar `pandas` ni `numpy`.
# - La colección documental deberá representarse inicialmente mediante una **lista de diccionarios**.
# - Las operaciones de insertar, consultar, actualizar y eliminar deben implementarse mediante funciones propias.
# - El código debe estar organizado, comentado y ejecutarse sin errores.
# - No es obligatorio instalar ni utilizar MongoDB; la base documental será simulada en Python.
#
# ## 6. Entregable
#
# Completar este notebook incluyendo:
#
# - Código fuente.
# - Resultados de ejecución.
# - Explicaciones solicitadas.
# - Conclusiones.
#
# El notebook debe ejecutarse de principio a fin sin errores.
#
# ## 7. Rúbrica de evaluación — 10 puntos
#
# | Criterio | Puntaje |
# |---|---:|
# | Adquisición correcta desde CSV, JSON y fuente simulada | 2.0 |
# | Identificación, validación y calidad de las fuentes | 1.5 |
# | Normalización e integración de datos | 2.0 |
# | Implementación de estructura y operaciones documentales | 2.0 |
# | Consultas y análisis de la información | 1.5 |
# | Organización, claridad del código y conclusiones | 1.0 |
# | **Total** | **10.0** |
#
# ## 8. Pregunta de reflexión
#
# **Una empresa recibe datos desde archivos CSV, documentos JSON y APIs. ¿Por qué es importante normalizar y validar los datos antes de almacenarlos en una base de datos orientada a documentos?** Relacione su respuesta con los problemas encontrados durante el desarrollo del caso.

# %% [markdown]
# ## Desarrollo — Parte A: Adquisición y fuentes de datos
# Cree los archivos solicitados, cargue las tres fuentes y muestre los resultados.

# %% [markdown]
# ## Desarrollo — Parte B: Evaluación y calidad de las fuentes
# Implemente las validaciones y explique las diferencias entre las fuentes.

# %% [markdown]
# ## Desarrollo — Parte C: Integración y normalización
# Construya `productos_integrados` con una estructura homogénea.

# %% [markdown]
# ## Desarrollo — Parte D: Base de datos orientada a documentos
# Implemente la colección documental y las operaciones CRUD solicitadas.

# %% [markdown]
# ## Desarrollo — Parte E: Análisis de la información integrada
# Calcule los indicadores solicitados y presente los resultados de manera clara.

# %% [markdown]
# ## Desarrollo — Parte F: Simulación de consultas documentales
# Implemente las consultas y responda las preguntas conceptuales.

# %% [markdown]
# ## Conclusiones
# Escriba una conclusión de 5 a 8 líneas sobre la adquisición, integración y almacenamiento documental de los datos.

# %% [markdown]
# ## Reflexión final
# Responda la pregunta de reflexión planteada en el enunciado.
